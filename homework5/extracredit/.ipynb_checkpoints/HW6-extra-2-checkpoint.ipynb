# %% [markdown]
# ## HW 6, Part 2:   Recurrent Neural Networks (RNN)  -- Extra Credit (40 points)

# %% [markdown]
# When it comes to model sequential data such as sentences, documents and videos, etc, the state of the art approach is to use Recurrent neural network (RNN). At each timestep, RNN takes an element (such as a word) as input, combines with past information encoded as a vector (such as all information in the sentence before this timestep), generate a new vector encoding both current input and past information, then delivers it to next timestep.
#
# For more details about LSTM (a very popular variant of RNN), please refer to http://colah.github.io/posts/2015-08-Understanding-LSTMs/ and here is a very good video explaining RNN: https://www.youtube.com/watch?v=WCUNPb-5EYI.

# %% [markdown]
# ### Generating text with Long Short-Term Memory Networks
#
# RNN can be used to generate text. For more information, please read: https://karpathy.github.io/2015/05/21/rnn-effectiveness/.
#
# The following is an example script to generate text from Nietzsche's writings.
#
# Note:
# - At least 10 epochs are required before the generated text
# starts sounding coherent, but more is better.
#
# - It is recommended to run this script on GPU, as recurrent
# networks are quite computationally intensive.
#
# - If you try this script on new data, make sure your corpus
# has at least ~100k characters. ~1M is better.

# %%
#Import necessary libraries 
from __future__ import print_function
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from tensorflow.keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io

# %%
#Get the data - available from amazon
path = get_file('nietzsche.txt', origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
with io.open(path, encoding='utf-8') as f:
    text = f.read().lower() # make it all lowercase 
print('corpus length:', len(text))

chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 600901/600901 [==============================] - 1s 1us/step
# corpus length: 600893
# total chars: 57

# %%
# Cut the text in semi-redundant sequences of maxlen characters
## Cut the text into a series of windows. 
## Each window is 40 characters
## The window moves 3 steps forward each step

maxlen = 40
step = 5
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

# Turn these sentances into one-hot encoded vectors
## For all words in the sentances, there is a one, else there is a zero in that index of the vector

print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
print('Done!')
# Out:
# nb sequences: 120171
# Vectorization...
# <ipython-input-3-b99405cc524d>:19: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
# <ipython-input-3-b99405cc524d>:20: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
# Done!

# %% [markdown]
# Now we have data to feed a model for text generation. Next  we build a LSTM model to fit the data. Using Keras this is only few lines of code!

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(learning_rate=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
print('Done!')
# Out:
# Build model...
# Done!

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.ma.log(preds)
    preds = preds.filled(0)
    preds = preds / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)


def on_epoch_end(epoch, logs):
    # clear_output()
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % (epoch+1))

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.4, 0.5, 1.0]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

# %% [markdown]
# # Training
# -  Each epoch takes up to 1 minute or so on a CPU (an epoch took 30 seconds for my PC)
# -  Recall that training on at least 20 epochs will give intelligible results
# -  So you're gonna have to let this run for a while (if ETA per epoch is bigger than 5 minutes on your machine, you can reduce the number of epochs)

# %%
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y,
          batch_size=128,
          epochs=10,
          callbacks=[print_callback])
# Out:
# Epoch 1/10
# 939/939 [==============================] - ETA: 0s - loss: 2.1086
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: " looks and emaciated bodies are eloquent"
#  looks and emaciated bodies are eloquent of the self-some and the self in the self the self the self-self the self the self the self the self
# the self the self the self-so the self-some the self-some the cousting the self the self-so the coust the self the self and and the self-so the self the self the self-so the self-sende and the self the self-some the sould the self-so shere the self the self the self the self the self the self the
# ----- diversity: 0.4
# ----- Generating with seed: " looks and emaciated bodies are eloquent"
#  looks and emaciated bodies are eloquent and the read and the sentions and self the self the man perhoph of the prole and every will man will the self in the most be all a sentive of ling in the self-some the fore of the coure the manter of the its and self-and the sont the self-some the dost in the simally as in the very man canaster of the stalled and the selfous in it man line the mather the self has the man is the self-so still self
# ----- diversity: 0.5
# ----- Generating with seed: " looks and emaciated bodies are eloquent"
#  looks and emaciated bodies are eloquent, and in is all generally prace, and the oner of the as it is
# precession or a still the self and wind the addance and the igreated at also a be only in the self with the self-something this self-say resimed the sence the coure for the existive that in mase the self-some nature the dead as as the "langer as for the earteon at the found of the strience and beligin and it a set this for the becertion
# ----- diversity: 1.0
# ----- Generating with seed: " looks and emaciated bodies are eloquent"
#  looks and emaciated bodies are eloquentman oneven of the ramode callates tome speal suncelable--there"with
# aplidey of cersonce, as elf?ous hove has ablane, respecscian
# affurrand, in is layouiony toinime
# councepons, evink, that what sacs
# mad on gish mact lodkes mato, be speardion refiling--eflibal, sont vease, they verymrear,,", in ate wickdy spectation. ot
# its deever popitly cuneiro, the s
# recage without these, it he sempowpers
# tobpana
# 939/939 [==============================] - 112s 118ms/step - loss: 2.1086
# Epoch 2/10
# 938/939 [============================>.] - ETA: 0s - loss: 1.7019
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "rld-standpoint
# (weltbetrachtung) and con"
# rld-standpoint
# (weltbetrachtung) and conscience the soul and the most sour of the most something the soul of the soct of the stind and the soul the spirit and the socients that the self the propers and in the the strong the problem and the something the sould that he are the socient of the soulfical of the soul of the most the former, the says and the world and the say, the soct of the self-sour the still to the desire the coungured the
# ----- diversity: 0.4
# ----- Generating with seed: "rld-standpoint
# (weltbetrachtung) and con"
# rld-standpoint
# (weltbetrachtung) and condition of the said to the desire that the prevent say of the deforing and the feelings, and the artifical encending that is a anter the artification which realient that is the heart of the recognical to strong the stronger with a so morality and the regard that he man of the deselvence and son the sour the propent than and the artifes it is a soct of the has it will has and end discivily and the s
# ----- diversity: 0.5
# ----- Generating with seed: "rld-standpoint
# (weltbetrachtung) and con"
# rld-standpoint
# (weltbetrachtung) and contrarity, the spears and itself and that the stronger, and stirals and morality, as the concepling in the discielize and the resire the self-desire in does it who lat of present and course and the most concepling and about the socren as the strong the loves and so
# man its something in general
# enously reachread of the fathers at a man--things it manife a dealogical of the darle and the heartion of t
# ----- diversity: 1.0
# ----- Generating with seed: "rld-standpoint
# (weltbetrachtung) and con"
# rld-standpoint
# (weltbetrachtung) and consciences, wind of decite many of "then are to men e sabuybhing in the josting abattent to preseral intrracacaps of
# regin, thing-tohe wis
# "not se predestrous
# rwardwing
# the cuevel"! but in doectrardu"ing a most opeepers havist, or do son ha we -ashit with
# shorthwin had, whiled, how ifience age sentire smadity, intear of
# peaces occed cassed suther whom when lac, to oblive of itnof, and chargoter schi
# 939/939 [==============================] - 112s 120ms/step - loss: 1.7022
# Epoch 3/10
# 939/939 [==============================] - ETA: 0s - loss: 1.5803
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: " the less true that more often we gnash "
#  the less true that more often we gnash of the such a man in the such a perstinction of the most and and the present and and such a perstinct of the man and and the present of the such a sorise in the present and something the conscience of the man and in the belief of the conscience of the conscience of the common the prise the the man and the persunting and the such the will under the present of the privility and say and the strange a
# ----- diversity: 0.4
# ----- Generating with seed: " the less true that more often we gnash "
#  the less true that more often we gnash of the such the conscience to and in the artist of the desurtion and the deal of the religion of the possible in the individually and commanding and the same and commonding under the masten in a permast the conscience of the man of the such the percustomed to the profest of the such the man of the suffering and the man and the beloods of an an and present of the the still of the high and faster of
# ----- diversity: 0.5
# ----- Generating with seed: " the less true that more often we gnash "
#  the less true that more often we gnash does not the truth of the feeling and the most conscierce and the had no powersting and the persuitation of the prigress evil the possible and standed and dees of the man of the consciences in an and presentive of men in itself only and the refines and does and pression of its and for the desirest and who has one however, and conscience the belief that a general son the preservally in his for the
# ----- diversity: 1.0
# ----- Generating with seed: " the less true that more often we gnash "
#  the less true that more often we gnash of the rimhl
# perhaws i "tyhinors in only also himself, the moralism. will tandes belief and for commondingly, in the vay will
# badtould this be snowrery of ehid of yoult of masting only feelinadally servibling to grand)).
#
# 12hiness about everything from all so and man alough resure
# and trags indectudisfolityos. the
# kligorations of the
# striguines of manfy charname spirits, ascaligizeds we may in sch
# 939/939 [==============================] - 111s 118ms/step - loss: 1.5803
# Epoch 4/10
# 939/939 [==============================] - ETA: 0s - loss: 1.5129
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: " the nations invented their
# mythologies,"
#  the nations invented their
# mythologies, and there is the strong to the master of the most consideral and there is the master of the master of the master of the master and social of the man to the striggation of the most of the master of the such a stranged to be and the master to a stranged and social and socistical desirated the most consideration of the master to the master of the master with the continess of the stranged to the mast
# ----- diversity: 0.4
# ----- Generating with seed: " the nations invented their
# mythologies,"
#  the nations invented their
# mythologies, which is to be own the pressing and something in the man to the most desiral and too to least of the strange, here is only which the power, as to the present to a socitured to the stupidity and any good and society with the consident to be one's soul of the work of the course of the master to accountations which the developing to the most man of the would the master of the most discibligions and
# ----- diversity: 0.5
# ----- Generating with seed: " the nations invented their
# mythologies,"
#  the nations invented their
# mythologies, and any longer to be and strong to with allotions.
#
#
#
#
#
#
# =all there is there is a more of the sunder of the more in the collect to the pressity of it is for the extent and so the will to the work of the such presunt to a suscection of the reason of the its as at a such of the human extent of a thiloly and being to there is a soll of the ausolety we longer to the soul of the strange and soul and s
# ----- diversity: 1.0
# ----- Generating with seed: " the nations invented their
# mythologies,"
#  the nations invented their
# mythologies, tavided a clay, dee, to during to unegosses
# the most intley. become to obtles, is prescribation, depentally nomanaiss, we very rided
# its in the meast the anviratives, too been wayk withhy good and noted bit feelings. the same. there is had belief more bedeed the
# dorent", everything; with these
# aves to to delial been more beotherngs,
# =aphe
# yourgeetly belood and curtual only, as the trage of notrom
# 939/939 [==============================] - 112s 119ms/step - loss: 1.5129
# Epoch 5/10
# 938/939 [============================>.] - ETA: 0s - loss: 1.4689
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "ogues, and was always many paces ahead o"
# ogues, and was always many paces ahead of the present and a personalical that the higher can as a seems to the sense that the character and the superfor the discannity of the strong the personal and strong the powerful that the conscience that it is the desires to the reason to have strive and a so the conscience that it is the states the sense the strong the compression of the conception of the discan of the discan that the soults of t
# ----- diversity: 0.4
# ----- Generating with seed: "ogues, and was always many paces ahead o"
# ogues, and was always many paces ahead of the comes that the most way so many and conscience that the characee that the for the states and ever whether is the deligion and processest, a deserved the could reference, as the places the philosophers of the being the reason that he desentiuated in the stribe the stander the personal conscience to for the same life the form of the reason of every himself that the
# sould the superfor a place o
# ----- diversity: 0.5
# ----- Generating with seed: "ogues, and was always many paces ahead o"
# ogues, and was always many paces ahead of persistitude what there is we more this gratious our falseherm, for the chanse that the soulth itself the longer are does regard to perhaps the comes
# the compromity of the own of the could the strong, the reason that he does to he dear which the
# philosophical and self detrial compression of the possible that his conscience nature of the discives as its as the
# have being the most have the chaster
# ----- diversity: 1.0
# ----- Generating with seed: "ogues, and was always many paces ahead o"
# ogues, and was always many paces ahead one been the readly compossible that love and souls,
# hard idais its are a now le dos, in a fundamental presenting, stoans of piveive insides no! i have languy,
# still product that it, very cleast himself, that canible of
# one avorlation, he well 'non the mane
# respectual for it is his orself,
# if there is estance of the polultion in short, the dongle and scheil stands, thather christianity word,
# that i
# 939/939 [==============================] - 112s 119ms/step - loss: 1.4689
# Epoch 6/10
# 938/939 [============================>.] - ETA: 0s - loss: 1.4351
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "d sternness of the dissecting hand, or a"
# d sternness of the dissecting hand, or a demonation of the same time and moral togetherer the self-detendence of the self-despined and self-detend and souls of the such a thing and thing and religious of the most morality of the self-despiness of the superficured to be and self and the contrary and self-despect of the most determant of the most extent of the such a self-despact, of the same time of the most moral something of the souls
# ----- diversity: 0.4
# ----- Generating with seed: "d sternness of the dissecting hand, or a"
# d sternness of the dissecting hand, or as the most desirned and all thing in the extent of morality and sense of contemption of the propers of the morality and discan always some problent of moral too sack to the superfitual of a contrained and always in the stupidity of the succession of the same among is a sort of the longer and in the same time and that were ourselves the togation to self-demong of a soul and propers of the religious
# ----- diversity: 0.5
# ----- Generating with seed: "d sternness of the dissecting hand, or a"
# d sternness of the dissecting hand, or a decome of exisping even which character, and the something and of say will can we has some to the look and and acter after the lightness. there is always there are strength of self-dank selections of thing-despable of then made to all thing remain for a superficured and presention of the conception of the world of the fact of all thing of get be truthfs of morality of a different singerous of a p
# ----- diversity: 1.0
# ----- Generating with seed: "d sternness of the dissecting hand, or a"
# d sternness of the dissecting hand, or all pospecty of called nowmell more nablion of myst when been a eway think of resprisuliation in
# his
# self gradly soul and fornerness the then and contemptar, it marth stoold a, exeliss otherw-reling valuation thit henguar," in the idper unfectedent mankind affelt were
# contempts vidinc indutrousion nawical and menture).
#
# ut it
# is not of the self-presels
# falseledy to been one would the engliaco. in f
# 939/939 [==============================] - 114s 122ms/step - loss: 1.4355
# Epoch 7/10
# 938/939 [============================>.] - ETA: 0s - loss: 1.4111
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "their taste,
# including the enmity and vo"
# their taste,
# including the enmity and voluntion of the deterioration of the such as the moral the such a strong the sense of the man and and so man and the the soul of the soul of the belief the the surche is the the such a contentive the higher for a power and should be also and should not the soul and also and the existence of the sense of the such as the such as the here and man also and the same time the such a god and and such a no
# ----- diversity: 0.4
# ----- Generating with seed: "their taste,
# including the enmity and vo"
# their taste,
# including the enmity and voluntion of the spirit of the propersal on the sunser and say the for the formar the man of the highest strong the susped of the moral
# the has something in other of the sulfers of the reason the thing is all the thing in the such the higher in the soul, and in the order the existence of the in the signs in its as in all the morality and dilitational and also here as the other of the could the great
# ----- diversity: 0.5
# ----- Generating with seed: "their taste,
# including the enmity and vo"
# their taste,
# including the enmity and voluntable man and extention of any religious of this man and should man in himself the instinct, and who from the personal that and the more influence and the more sure of the art of any many and and man alrest the also mankind, right of the same
# the the strengt that with the about the more any will the considered of the individual and should not be the world and should not the insigns, which a sur
# ----- diversity: 1.0
# ----- Generating with seed: "their taste,
# including the enmity and vo"
# their taste,
# including the enmity and volcumnts of the chanxular show storm of
# other in the simuestion we-derighte, name.--one
# whe lad has be religious in coumaciom as him in
# dim2fultions; not only, who
# iwavic, there one-, it thinker was ulmost of high ensire re, their proof disifferents. i selles--"garlen adviemer, along
# callswardly bystrely retaid
# perhaps geejonk of heal, indeffes the absirations
# as i purbose becimess with adverreand
# 939/939 [==============================] - 112s 119ms/step - loss: 1.4114
# Epoch 8/10
# 939/939 [==============================] - ETA: 0s - loss: 1.3917
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "hortness of human life leads to many err"
# hortness of human life leads to many error of the sense of the spirit and the sense of the soul-and the stronger of the same time of the soul--the soul-and to the soul-and the souls of the soul-and also a sort of the same time of the soul-dong the suspection of the soul-and the sentimes of the such a soul of the same time the continue to the spirit and be the soul-and also a sort of the sense the sentimes and also the soul--the possible
# ----- diversity: 0.4
# ----- Generating with seed: "hortness of human life leads to many err"
# hortness of human life leads to many error of the said the future of the more personal and fechard as a serve and the spirit especially and sense of the consorable the personal and so master. the continue to the soul--as reverity of the been has to the sireling of the same time of the spirits, and the same time the sense of the personess and the sentimes of the spirit and sense of the more poecess of the possible recalled and the feelin
# ----- diversity: 0.5
# ----- Generating with seed: "hortness of human life leads to many err"
# hortness of human life leads to many error to the superiority, and self-contimed the more problement, the world that desire the perforth and also the more individual and the pressed the provemed to the religious has have been and to person as our also and every being the stands and for the stronger in the world and perilition of the conscience of the restormed to make the morality and to the stangouist the signs and the modelic life--no
# ----- diversity: 1.0
# ----- Generating with seed: "hortness of human life leads to many err"
# hortness of human life leads to many errors. and
# as precient refferentible of him of the formoum
# individual one
# the feeling was one man elessics of all of the a exhis of arts mews in all the lord perimins of many good and ofcipted
# freer..
#
# dite in indifference of the most fable rightness, is t seeven in what still part of devecred; in generation of the compirernes.
#
#
# id helpescoffinity li) a man ati is not resolently
# he we the while of
# 939/939 [==============================] - 113s 121ms/step - loss: 1.3917
# Epoch 9/10
# 938/939 [============================>.] - ETA: 0s - loss: 1.3736
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: " reminded that schopenhauer, although a "
#  reminded that schopenhauer, although a servies of the suspacical and the such a suspachs, and the such a strong the morality and the suspachs. it is the suspacical and all the extendent of the supposition of the subtle and the such a strong the subjection of the morality of the supposition of the sense of the sublimed and extenders and the such a decreation of the conception of the supposition of the morality to the contrary to the suc
# ----- diversity: 0.4
# ----- Generating with seed: " reminded that schopenhauer, although a "
#  reminded that schopenhauer, although a more a more in the supposition of the sense of the pressing the struatity, and every proofs a man of the morality of health and also the sense of the subtliness of the such its trature of the deed in the conscience of the most from the spirit in the soul-and and devilry and in contempoused in viced the supposed to the other
# of the fail even the subtling and former and the most former of the most c
# ----- diversity: 0.5
# ----- Generating with seed: " reminded that schopenhauer, although a "
#  reminded that schopenhauer, although a little a through still with the being and in the strong to the finule of the easily a servies and a strong
# and not the cause of the establishess of the unconsidered to the morality of the soully and prigorive and of the stands, the distral recome the compression in the extinctingly and which is the
# self--and of the most conscience to the case in our religious
# belophers and with it is in the result
# ----- diversity: 1.0
# ----- Generating with seed: " reminded that schopenhauer, although a "
#  reminded that schopenhauer, although a as a
# being some valw atill and even
# point of allost say to the hard--trituatinek wither usually
# declinam, to the moralitt
# of else
# regarged and imprecisto belief
#
# noble surcicus
# lack of
# most most
# camewis propress.
# swarts ones
# secustally considing heary of god,
# evil
# called now has naturatic am preservation
# recowed whither vip. we never be -we deed of the dudd in somewivh who knowicatesn--but, the d
# 939/939 [==============================] - 116s 124ms/step - loss: 1.3735
# Epoch 10/10
# 939/939 [==============================] - ETA: 0s - loss: 1.3596
# ----- Generating text after Epoch: 10
# ----- diversity: 0.2
# ----- Generating with seed: "
# logic and of the straight line, hankeri"
#
# logic and of the straight line, hankeriver, in the supposed to the supposition the most disposition of the supposition to the supposition of the most supposed the souls of the most supposed to the senses and an instincts of the most supposed the such a provence of the spirit of the spirit of the supposition of the souls. they seems to be more power of the souls, and so the souls of the most such a most supposed to the suspicious and so
# ----- diversity: 0.4
# ----- Generating with seed: "
# logic and of the straight line, hankeri"
#
# logic and of the straight line, hankeriver, in the most spirit philosophers of the states of the spirit and soul of the spirit of the most decivited the supposition of the supposition of the surpation of the same the sancuar itself these himself has been so the same of the souls of the sound and the spirit of a considerer to be actual to the souls, and of the conscience of the soul--is a most provence of the proporcary has recondation
# ----- diversity: 0.5
# ----- Generating with seed: "
# logic and of the straight line, hankeri"
#
# logic and of the straight line, hankeriver, it work of the dangerous and conscience of the propers, it is suffer the proper the great order to a still long short of as a still of the fact the free, he then and senses of even
# instrument of the state of the most being to even itself, and the soul of the supposes and an some
# order and conscience of a despinaise the supposition the spirit to such as the heart in the trage in the extent to
# ----- diversity: 1.0
# ----- Generating with seed: "
# logic and of the straight line, hankeri"
#
# logic and of the straight line, hankeriver who ought it smee where, the
# slave--a new dacrfully long sucm to trive great whole to art heart, endomaness,aze
# draye to sahiticiem for unfation. if of bleves. thisking, as a peature and youth his cause
# of shortmen not all they have soul because of the knowled the work of
# soor rightrishness of an undancly or to out perceive hanaient of shmaris. a word usual and the inserfiting for understrothe
# 939/939 [==============================] - 112s 119ms/step - loss: 1.3596

# %%
from numpy import *

# %% [markdown]
# ## Load pre-trained model
# Since it is time consuming to train this LSTM model with CPU for more epochs, we provided a pre-trained model which is trained on GPU for 100 epochs. Use the following code to check how coherency the model is.
#
# It requires h5py packages, please install it to test the following code.

# %%
# build the model: a single LSTM
print('Load pre-trained model...')
from keras.models import load_model
model = load_model('shakespear200.h5')


def lstm_generate(seed, model):
    orig_seed = seed
    for diversity in [0.2, 0.3, 0.5, 1.0]:
        print('----- diversity:', diversity)
        seed = orig_seed
        generated = ''
        generated += seed
        print('----- Generating with seed: "' + seed + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(seed):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            seed = seed[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()


seed = "from an anguish with which no other is t"
# seed = "thou art"
lstm_generate(seed, model)
# Out:
# Load pre-trained model...
# ----- diversity: 0.2
# ----- Generating with seed: "from an anguish with which no other is t"
# from an anguish with which no other is the consciousness, the more the subjection of the state of the more expedient and the sense, and the states of the present the present of the sense of the present the sense of such a present in the serve the subjection of the subjection of the something the subjection of the sense of the state of the present is the consideration of the consideration of the subjection of man and superficial and some
# ----- diversity: 0.3
# ----- Generating with seed: "from an anguish with which no other is t"
# from an anguish with which no other is the sense of the sense of the state to the subjection of the probably the present in the sort, and for the subjection of the finer the present to the consequ? the serve the reality of the fact the concesses of the state the contradictic the subjection of the standards of the world to the present the sake it is a hearts of the such a man is the subjection of the rest to the sense of the subjection o
# ----- diversity: 0.5
# ----- Generating with seed: "from an anguish with which no other is t"
# from an anguish with which no other is to such a states, the sense of such the consciousness, and become nor all something the consciousness and probably higher the command in the religious consequxing and first, and it is the recelly such a passe. the present their such a the interpretation and the marter, the compared in the one play in the sense of things to the world, and superfection of mankind, which is not beliefs that the subjec
# ----- diversity: 1.0
# ----- Generating with seed: "from an anguish with which no other is t"
# from an anguish with which no other is the virtuouan "thing in the capacity is the knowledge. he were necessary action, fruedome, when it be evilst unexplacious hough platers, more experiences for remoening and arn german
# limitual
# great and action the namel of the great philtle, who
# great writing
# in riddest does not he existence of thing to as marbable should compance of decision of the is overschy itself far heven echonous over the int

# %% [markdown]
# ### Exercise: use LSTM to generate baby names
# -  The following data set contains 8000 last names. You can download and process the name data set as follows:
#
# ```python
# name_path = get_file('names.txt', origin='http://www.cs.cmu.edu/afs/cs/project/ai-repository/ai/areas/nlp/corpora/names/other/names.txt')
# with io.open(name_path, encoding='utf-8') as f:
#     text = f.read() # make it all lowercase
#
# text = text.split()
# text = ', '.join(text)
# ```
#
# Using the last name data set, answer the following questions:
#
# 1. (30 points) Train a LSTM to generate the names. How long does it take to train? How coherent does it sound?
# 2. (10 points) Can you train the LSTM, but for every epoch, shuffle the order of names before call model.fit()? How long does it take to train? Does it improve the coherency?
